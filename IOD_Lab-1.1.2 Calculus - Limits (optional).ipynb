# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>
#
# # Calculus - Limits

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-2.0.3-cp39-cp39-macosx_10_9_x86_64.whl (11.8 MB)
#      |████████████████████████████████| 11.8 MB 1.7 MB/s eta 0:00:01    |██████▎                         | 2.3 MB 1.5 MB/s eta 0:00:07     |███████████████▉                | 5.9 MB 2.8 MB/s eta 0:00:03MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.20.3 in /Users/stephaniezefferino/Library/Python/3.9/lib/python/site-packages (from pandas) (1.25.2)
# Collecting pytz>=2020.1
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      |████████████████████████████████| 502 kB 2.1 MB/s eta 0:00:01    |██████▌                         | 102 kB 2.1 MB/s eta 0:00:01     |█████████████▊                  | 215 kB 2.1 MB/s eta 0:00:01
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      |████████████████████████████████| 341 kB 954 kB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/stephaniezefferino/Library/Python/3.9/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# Installing collected packages: tzdata, pytz, pandas
# Successfully installed pandas-2.0.3 pytz-2023.3 tzdata-2023.3
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt

# get matplot to show charts inline
# %matplotlib inline

# %%
# define a function, say f(x) = 1/x
def f(x):
    return 1/x

# %%
# calculate value of f(x) for some values
print('f(4) = ',f(4))
# Out:
# f(4) =  0.25

# %%
# calculate value of f(x) for 0
print('f(0) = ', f(0))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-4-6fc9ceaa90ed> in <module>()
# ----> 1 print('f(0) = ',f(0))
#
# <ipython-input-2-504787a1337b> in f(x)
#       1 def f(x):
# ----> 2     return 1/x
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Plot y versus x as lines and/or markers.
#
# > matplotlib.pyplot.plot
#
# [matplotlib.pyplot.plot](https://matplotlib.org/3.1.0/api/_as_gen/matplotlib.pyplot.plot.html)

# %%
# plot f(x) from a small number to a large number
x = np.arange(0.1,100,1)
y = f(x)
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()
plt.show()

# %% [markdown]
# Plot f(x) from a small number to a large number with logarithmic scale.
#
# > Hint: plt.yscale('log')

# %%
# plot f(x) from a small number to a large number with logarithmic scale
x = np.arange(0.1,100,1)
y = f(x)
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.yscale('log')
plt.grid()
plt.show()

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2023 Institute of Data
#
#
# ---
#
#
#
# ---
